# %% [markdown]
# # Validations:

# %%
# 1. There are no 0/NaN values (each row has all values)

notna = df.notna()
if False in notna: 
    print ('False')
else: 
    print ("No NaN/empty values found")
# Out:
# No NaN/empty values found

# %%
# 2. ACT_time 
df2 = pd.read_csv('2023-05-02.csv')
df2.describe()
# Out:
#        EVENT_NO_TRIP  EVENT_NO_STOP    VEHICLE_ID        METERS      ACT_TIME  \
# count   1.595883e+06   1.595883e+06  1.595883e+06  1.595883e+06  1.595883e+06
# mean    2.254578e+08   2.254579e+08  3.584709e+03  1.139352e+05  5.264725e+04
# std     1.521086e+05   1.521085e+05  3.665828e+02  7.983497e+04  1.754781e+04
# min     2.251020e+08   2.251020e+08  3.002000e+03  0.000000e+00  1.453700e+04
# 25%     2.253839e+08   2.253839e+08  3.240000e+03  5.021900e+04  3.859300e+04
# 50%     2.254428e+08   2.254428e+08  3.603000e+03  1.002640e+05  5.223500e+04
# 75%     2.255029e+08   2.255030e+08  3.940000e+03  1.603220e+05  6.571800e+04
# max     2.262739e+08   2.262739e+08  4.239000e+03  4.638060e+05  9.745300e+04
#
#        GPS_LONGITUDE  GPS_LATITUDE  GPS_SATELLITES      GPS_HDOP
# count   1.594485e+06  1.594485e+06    1.595879e+06  1.595879e+06
# mean   -1.226582e+02  4.550514e+01    1.149195e+01  8.399454e-01
# std     1.198388e-01  5.079153e-02    1.019764e+00  4.223295e-01
# min    -1.231159e+02  4.528508e+01    0.000000e+00  4.000000e-01
# 25%    -1.227079e+02  4.548813e+01    1.100000e+01  7.000000e-01
# 50%    -1.226543e+02  4.551019e+01    1.200000e+01  8.000000e-01
# 75%    -1.225790e+02  4.553376e+01    1.200000e+01  9.000000e-01
# max    -1.223329e+02  4.563013e+01    1.200000e+01  2.310000e+01

# %%
df2.sort_values(by=['METERS'], ascending=True)
# Out:
#          EVENT_NO_TRIP  EVENT_NO_STOP            OPD_DATE  VEHICLE_ID  METERS  \
# 177577       225346786      225346788  24DEC2022:00:00:00        3024       0
# 731830       225434145      225434147  24DEC2022:00:00:00        3905       0
# 731829       225434145      225434147  24DEC2022:00:00:00        3905       0
# 731828       225434145      225434147  24DEC2022:00:00:00        3905       0
# 731827       225434145      225434147  24DEC2022:00:00:00        3905       0
# ...                ...            ...                 ...         ...     ...
# 1584354      226272142      226272155  24DEC2022:00:00:00        3267  463750
# 1584355      226272142      226272155  24DEC2022:00:00:00        3267  463776
# 1584356      226272142      226272155  24DEC2022:00:00:00        3267  463790
# 1584357      226272142      226272156  24DEC2022:00:00:00        3267  463796
# 1584358      226272142      226272156  24DEC2022:00:00:00        3267  463806
#
#          ACT_TIME  GPS_LONGITUDE  GPS_LATITUDE  GPS_SATELLITES  GPS_HDOP
# 177577      31921    -122.843165     45.503723            12.0       0.7
# 731830      33041    -122.563450     45.495052            12.0       0.7
# 731829      33036    -122.563447     45.495050            12.0       0.7
# 731828      33031    -122.563447     45.495050            12.0       0.7
# 731827      33026    -122.563447     45.495050            12.0       0.7
# ...           ...            ...           ...             ...       ...
# 1584354     88317    -122.844470     45.503762            12.0       0.7
# 1584355     88322    -122.844663     45.503567            12.0       0.7
# 1584356     88327    -122.844730     45.503440            12.0       0.7
# 1584357     88347    -122.844753     45.503390            12.0       0.7
# 1584358     88352    -122.844795     45.503303            12.0       0.7
#
# [1595883 rows x 10 columns]

# %%
act_time = df2['ACT_TIME']
act_time.describe()
act_time.max()
# Out:
# 97453

# %%
# 3. A trip should have a trip number as well as a vehicle number. 
# The code for #1 should cover this

# %%
# 4. Every same trip number should have the same vehicle number 
# trips = df.groupby(['EVENT_NO_TRIP']).mean()
trips = df['EVENT_NO_TRIP'].unique()
trips.size
# Out:
# 5751

# %%
# 5. There are a few millions records daily but not more (>5mil = alarm)
df['EVENT_NO_TRIP'].size
# Out:
# 216463

# %%
# 6. The date should always be the same in every row ****NOT VALID W/ TIMESTAMP****
date = df['OPD_DATE'].unique()
date.size
# Out:
# 1

# %%
# 7. The velocity should conform to a (normal?) distribution - max/min/mean speeds 
# Can't do without transformation

# %% [markdown]
# # Transformation -> SQL tables

# %%
# df['c']=df['b'].apply(lambda x: 0 if x ==0 else math.log(x))

# %%
import pandas as pd
from datetime import datetime, timedelta

# df = pd.read_json('2023-05-10.json')
# df = pd.read_csv('2023-04-30.csv')
df = pd.read_csv('2023-05-02.csv')
df = df.drop(columns=['EVENT_NO_STOP', 'GPS_SATELLITES', 'GPS_HDOP'])

def create_timestamp(i):
    date = datetime.strptime(i['OPD_DATE'],'%d%b%Y:%H:%M:%S')
    time = timedelta(seconds=i['ACT_TIME'])
    return date + time 
    
df['TIMESTAMP'] = df.apply(create_timestamp,axis=1)
df = df.drop(columns=['OPD_DATE', 'ACT_TIME'])

def speed(meters, time):
    speed = meters/time
    return speed

df['dMETERS'] = df['METERS'].diff()
df['dTIMESTAMP'] = df['TIMESTAMP'].diff()
df['SPEED'] = df.apply(lambda row: speed(row['dMETERS'],row['dTIMESTAMP'].total_seconds()), axis=1)
df = df.drop(columns=['dMETERS','dTIMESTAMP'])

# Code that sets first breadcrumb value to second (not currently for all trips)
# df.sort_values(by='EVENT_NO_TRIP', na_position='first')
# df.iloc[0,6] = df.iloc[1,6]
df
# Out:
#          EVENT_NO_TRIP  VEHICLE_ID  METERS  GPS_LONGITUDE  GPS_LATITUDE  \
# 0            225101971        3026      41    -122.843865     45.504043
# 1            225101971        3026      55    -122.844035     45.504027
# 2            225101971        3026      73    -122.844193     45.503905
# 3            225101971        3026      94    -122.844347     45.503757
# 4            225101971        3026     117    -122.844518     45.503583
# ...                ...         ...     ...            ...           ...
# 1595878      226273658        4062  235224    -122.618797     45.562777
# 1595879      226273658        4062  235281    -122.618075     45.562773
# 1595880      226273658        4062  235338    -122.617338     45.562767
# 1595881      226273658        4062  235395    -122.616600     45.562758
# 1595882      226273658        4062  235458    -122.615805     45.562755
#
#                   TIMESTAMP  SPEED
# 0       2022-12-24 15:23:35    NaN
# 1       2022-12-24 15:23:40   2.80
# 2       2022-12-24 15:23:45   3.60
# 3       2022-12-24 15:23:50   4.20
# 4       2022-12-24 15:23:55   4.60
# ...                     ...    ...
# 1595878 2022-12-24 23:26:00  10.00
# 1595879 2022-12-24 23:26:04  14.25
# 1595880 2022-12-24 23:26:09  11.40
# 1595881 2022-12-24 23:26:14  11.40
# 1595882 2022-12-24 23:26:19  12.60
#
# [1595883 rows x 7 columns]

# %%
df.isna().sum()
# print(notna)
# Out:
# EVENT_NO_TRIP       0
# VEHICLE_ID          0
# METERS              0
# GPS_LONGITUDE    1398
# GPS_LATITUDE     1398
# TIMESTAMP           0
# SPEED               1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# EVENT_NO_TRIP    0
# VEHICLE_ID       0
# METERS           0
# GPS_LONGITUDE    0
# GPS_LATITUDE     0
# TIMESTAMP        0
# SPEED            0
# dtype: int64

# %%
df.hist(column='SPEED',xlabelsize=[])
# Out:
# array([[<Axes: title={'center': 'SPEED'}>]], dtype=object)

# %%
df.sort_values(by=['GPS_LONGITUDE', 'GPS_LATITUDE'], na_position='first')
# Out:
#          EVENT_NO_TRIP  VEHICLE_ID  METERS  GPS_LONGITUDE  GPS_LATITUDE  \
# 8158         225112774        3203  180973            NaN           NaN
# 28586        225152037        4033   63663            NaN           NaN
# 28622        225152037        4033   64661            NaN           NaN
# 29856        225152447        4033  204365            NaN           NaN
# 33626        225153019        4033  393400            NaN           NaN
# ...                ...         ...     ...            ...           ...
# 1006016      225473802        3620   44895    -122.332923     45.285392
# 1423294      225536772        3946   98274    -122.332923     45.285407
# 338395       225375704        3714  112724    -122.332918     45.285522
# 1009236      225473968        3620  132846    -122.332918     45.285585
# 345606       225375553        3714   44215    -122.332917     45.285538
#
#                   TIMESTAMP  SPEED
# 8158    2022-12-24 18:20:37    7.2
# 28586   2022-12-24 08:35:59    4.2
# 28622   2022-12-24 08:43:49    8.2
# 29856   2022-12-24 15:07:47    4.8
# 33626   2022-12-24 23:30:06    2.2
# ...                     ...    ...
# 1006016 2022-12-24 09:24:11    6.5
# 1423294 2022-12-24 11:24:03    6.6
# 338395  2022-12-24 15:52:23    3.6
# 1009236 2022-12-24 12:25:05    3.8
# 345606  2022-12-24 13:37:08    4.0
#
# [1595883 rows x 7 columns]

# %%
df.fillna(0)
# Out:
#          EVENT_NO_TRIP  VEHICLE_ID  METERS  GPS_LONGITUDE  GPS_LATITUDE  \
# 0            225101971        3026      41    -122.843865     45.504043
# 1            225101971        3026      55    -122.844035     45.504027
# 2            225101971        3026      73    -122.844193     45.503905
# 3            225101971        3026      94    -122.844347     45.503757
# 4            225101971        3026     117    -122.844518     45.503583
# ...                ...         ...     ...            ...           ...
# 1595878      226273658        4062  235224    -122.618797     45.562777
# 1595879      226273658        4062  235281    -122.618075     45.562773
# 1595880      226273658        4062  235338    -122.617338     45.562767
# 1595881      226273658        4062  235395    -122.616600     45.562758
# 1595882      226273658        4062  235458    -122.615805     45.562755
#
#                   TIMESTAMP  SPEED
# 0       2022-12-24 15:23:35   0.00
# 1       2022-12-24 15:23:40   2.80
# 2       2022-12-24 15:23:45   3.60
# 3       2022-12-24 15:23:50   4.20
# 4       2022-12-24 15:23:55   4.60
# ...                     ...    ...
# 1595878 2022-12-24 23:26:00  10.00
# 1595879 2022-12-24 23:26:04  14.25
# 1595880 2022-12-24 23:26:09  11.40
# 1595881 2022-12-24 23:26:14  11.40
# 1595882 2022-12-24 23:26:19  12.60
#
# [1595883 rows x 7 columns]

# %% [markdown]
# # Transforming DF to SQL param tables:
# | BreadCrumb      | Trip |
# | ----------- | ----------- |
# | tstamp      | trip_id       |
# | latitude   | route_id        |
# | longitude   | vehicle_id        |
# | speed   | service_key        |
# | trip_id   | direction        |

# %%
# df.rename({'Courses': 'Course_ Name','Fee': 'CourseFee', 'Duration': 'CourseDuration'}, 
#           axis = "columns", inplace = True) 
BreadCrumb = df[['TIMESTAMP','GPS_LATITUDE', 'GPS_LONGITUDE', 'SPEED', 'EVENT_NO_TRIP']].copy()
BreadCrumb.rename({'TIMESTAMP': 'tstamp', 'GPS_LATITUDE': 'latitude', 'GPS_LONGITUDE':'longitude', 'SPEED':'speed', 'EVENT_NO_TRIP':'trip_id'}, axis='columns', inplace=True)
BreadCrumb.head(5)
# Out:
#                tstamp   latitude   longitude  speed    trip_id
# 1 2022-12-24 15:23:40  45.504027 -122.844035    2.8  225101971
# 2 2022-12-24 15:23:45  45.503905 -122.844193    3.6  225101971
# 3 2022-12-24 15:23:50  45.503757 -122.844347    4.2  225101971
# 4 2022-12-24 15:23:55  45.503583 -122.844518    4.6  225101971
# 5 2022-12-24 15:24:00  45.503403 -122.844673    4.8  225101971

# %%
# Trip should have all unique trips (unique EVENT_NO_TRIPs)
Trip = df[['EVENT_NO_TRIP', 'VEHICLE_ID']].copy()
Trip.rename({'EVENT_NO_TRIP':'trip_id', 'VEHICLE_ID':'vehicle_id'},axis='columns',inplace=True)
# Trip['EVENT_NO_TRIP'] = Trip['EVENT_NO_TRIP']

Trip.insert(loc=1, column='route_id', value=-1)
Trip.insert(loc=3, column='service_key', value=None)
Trip.insert(loc=4, column='direction', value=None)

Trip = Trip.drop_duplicates(subset=['trip_id'])
Trip.head(5)
# Out:
#             trip_id  route_id   vehicle_id
# count  3.541000e+03    3541.0  3541.000000
# mean   2.254575e+08      -1.0  3569.322790
# std    1.526182e+05       0.0   363.677543
# min    2.251020e+08      -1.0  3002.000000
# 25%    2.253833e+08      -1.0  3239.000000
# 50%    2.254425e+08      -1.0  3572.000000
# 75%    2.255060e+08      -1.0  3930.000000
# max    2.262739e+08      -1.0  4239.000000

# %%
df.describe()
# Out:
#        EVENT_NO_TRIP    VEHICLE_ID        METERS  GPS_LONGITUDE  GPS_LATITUDE  \
# count   1.594484e+06  1.594484e+06  1.594484e+06   1.594484e+06  1.594484e+06
# mean    2.254579e+08  3.584925e+03  1.139581e+05  -1.226582e+02  4.550514e+01
# std     1.521310e+05  3.664581e+02  7.984474e+04   1.198388e-01  5.079155e-02
# min     2.251020e+08  3.002000e+03  0.000000e+00  -1.231159e+02  4.528508e+01
# 25%     2.253839e+08  3.242000e+03  5.022800e+04  -1.227079e+02  4.548813e+01
# 50%     2.254428e+08  3.603000e+03  1.002990e+05  -1.226543e+02  4.551019e+01
# 75%     2.255029e+08  3.940000e+03  1.603530e+05  -1.225790e+02  4.553376e+01
# max     2.262739e+08  4.239000e+03  4.638060e+05  -1.223329e+02  4.563013e+01
#
#               SPEED
# count  1.594484e+06
# mean   8.027893e+00
# std    4.680554e+00
# min   -1.280369e+03
# 25%    4.800000e+00
# 50%    8.200000e+00
# 75%    1.100000e+01
# max    1.970000e+02
