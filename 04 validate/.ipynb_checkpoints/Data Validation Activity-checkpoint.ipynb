# %%
import pandas as pd

data = pd.read_csv("Hwy26Crashes2019_S23.csv")

data
# Out:
#       Crash ID  Record Type  Vehicle ID  Participant ID  \
# 0      1809119            1         NaN             NaN
# 1      1809119            2   3409578.0             NaN
# 2      1809119            3   3409578.0       3887884.0
# 3      1809119            2   3409579.0             NaN
# 4      1809119            3   3409579.0       3887885.0
# ...        ...          ...         ...             ...
# 2734   1860771            1         NaN             NaN
# 2735   1860771            2   3503992.0             NaN
# 2736   1860771            3   3503992.0       3991482.0
# 2737   1860771            2   3503993.0             NaN
# 2738   1860771            3   3503993.0       3991483.0
#
#       Participant Display Seq#  Vehicle Coded Seq#  Participant Vehicle Seq#  \
# 0                          NaN                 NaN                       NaN
# 1                          NaN                 1.0                       NaN
# ...

# %%
"""Assertion that all crash IDs have a record type field (existence)"""
def crashID_has_recordType(): 
    for i in range(2739):
        if data.iloc[i]['Crash ID'] > 0 and data.iloc[i]['Record Type'] > 0:
            return True

crashID_has_recordType()
# Out:
# True

# %%
def hour_limits(i):
    valid = True; 
    if i > 24 or i < 0:
        valid = False
    return valid
        
# data['Crash Hour'].head(12)
hours = data['Crash Hour'].apply(hour_limits)
hours.head(12)
# Trying to figure out how to test if 'hours' has any False- 'False' in hours not working
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# Name: Crash Hour, dtype: bool
